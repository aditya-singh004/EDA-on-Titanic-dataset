# %% [markdown]
# Welcome to AryaVerse

# %%
print("Hello AryaVerse with python")
# Out:
# Hello AryaVerse with python

# %%
print("Hello AryaVerse with python and vscode")
# Out:
# Hello AryaVerse with python and vscode

# %%
print("This is a cell")
# Out:
# This is a cell

# %%
import numpy as np

# %% [markdown]
# Creating Array from List

# %%
arr_1d=np.array([1,2,3,4])
print("1D Array: ",arr_1d)

arr_2d=np.array([[1,2,3],[2,3,4]])
print("2D Array: ",arr_2d)
# Out:
# 1D Array:  [1 2 3 4]
# 2D Array:  [[1 2 3]
#  [2 3 4]]

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
str="Aditya Aryan Singh Rajput"
print (str)
# Out:
# Aditya Aryan Singh Rajput

# %%
str.isalnum()
# Out:
# False

# %%
type(str)
# Out:
# str

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
str.isalpha() and str.isnum()
# Out:
# False

# %%
lst=[]
type(lst)
# Out:
# list

# %%
lst=['apple',2004,'aryan']
print(lst)
# Out:
# ['apple', 2004, 'aryan']

# %%
len(lst)
# Out:
# 3

# %%
lst.append('Aditya')
print(lst)
len(lst)
# Out:
# ['apple', 2004, 'aryan', 'Aditya', 'Aditya']
# 5

# %%
print (lst[3])
# Out:
# Aditya

# %%
lst.insert(3,'YOHO')
print(lst)
# Out:
# ['apple', 2004, 'aryan', 'YOHO', 'YOHO', 'YOHO', 'Aditya', 'Aditya']

# %%
lst[3]='18'
print(lst)
lst.append([18,9,2004])
print(lst)
lst.extend([6,1,2026])
print(lst)
# Out:
# ['apple', 2004, 'aryan', '18', 'YOHO', 'YOHO', 'Aditya', 'Aditya', [18, 9, 2004], [18, 9, 2004], 6, 1, 2026]
# ['apple', 2004, 'aryan', '18', 'YOHO', 'YOHO', 'Aditya', 'Aditya', [18, 9, 2004], [18, 9, 2004], 6, 1, 2026, [18, 9, 2004]]
# ['apple', 2004, 'aryan', '18', 'YOHO', 'YOHO', 'Aditya', 'Aditya', [18, 9, 2004], [18, 9, 2004], 6, 1, 2026, [18, 9, 2004], 6, 1, 2026]

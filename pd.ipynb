# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4), index=['R1','R2','R3','R4','R5'], columns=['C1', 'C2', 'C3', 'C4'])

# %%
df.head()
# Out:
#     C1  C2  C3  C4
# R1   0   1   2   3
# R2   4   5   6   7
# R3   8   9  10  11
# R4  12  13  14  15
# R5  16  17  18  19

# %%
df.to_csv('Test.csv')

# %%
df.loc['R1']
# Out:
# C1    0
# C2    1
# C3    2
# C4    3
# Name: R1, dtype: int64

# %%
type(df.loc['R1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2, 1:2]
# Out:
#     C2
# R1   1
# R2   5

# %%
type(df.iloc[0:2, 1:2])
# Out:
# pandas.core.frame.DataFrame
